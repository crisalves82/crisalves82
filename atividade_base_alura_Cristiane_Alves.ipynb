# %% [markdown]
# <a href="https://colab.research.google.com/github/crisalves82/crisalves82/blob/main/atividade_base_alura_Cristiane_Alves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(50)
# Out:
#                                        Rua                    Bairro  \
# 9872             Rua Franklin Lewis Gemmel  Parque Residencial Julia
# 991               Rua Conselheiro Zacarias           Jardim Paulista
# 8499                 Rua Cristóvão Pereira                Campo Belo
# 7631                                   NaN         Brooklin Paulista
# 8921               Rua João Nicolau Chamma    Jardim Virginia Bianca
# 7061                                   NaN           Chácara Inglesa
# 8108              Rua Maestro Chiaffarelli           Jardim Paulista
# 3463              Rua Doutor Sérgio Fleury           Vila Leopoldina
# 368                           Rua Pirituba              Mirandópolis
# 489             Rua Morais de Barros, 367                 Campo Belo
# 2892                       Rua Tordesilhas                      Lapa
# 5711                                   NaN             Lar São Paulo
# 8207                                   NaN               Jardim Peri
# ...

# %%
dados["Bairro"][5592]
# Out:
# 'Lapa'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Vagas"].mean()
# Out:
# 4.097222222222222

# %%
sum((dados["Bairro"] == "Lapa"))
# Out:
# 36

# %%
imoveis_lapa =( dados["Bairro"] == "Lapa")
imoveis_lapa
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_lapa1 = dados[imoveis_lapa]
imoveis_lapa1
# Out:
#                                             Rua Bairro     Cidade  Metragem  \
# 178                              Rua Guararapes   Lapa  São Paulo       515
# 729                              Rua Guararapes   Lapa  São Paulo       426
# 748                              Rua Guararapes   Lapa  São Paulo       170
# 935                                  Rua Cuevas   Lapa  São Paulo       650
# 977   Praça Senador José Roberto Leite Penteado   Lapa  São Paulo       330
# 1056                             Rua Dom João V   Lapa  São Paulo       145
# 1093                             Rua Dom João V   Lapa  São Paulo       150
# 1714                                        NaN   Lapa  São Paulo       380
# 1812                                        NaN   Lapa  São Paulo       385
# 2096                                        NaN   Lapa  São Paulo       363
# 2200                                        NaN   Lapa  São Paulo       368
# ...

# %%
imoveis_lapa1["Metragem"].mean()
# Out:
# 297.4166666666667

# %%
imoveis_lapa1["Vagas"].mean()
# Out:
# 4.722222222222222

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
imoveis_bairro = dados["Bairro"].value_counts()
imoveis_bairro.head(20).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.query('Bairro == "Morumbi"')['Metragem'].mean()
# Out:
# 609.1142857142858

# %%
dados.query('Bairro == "Alto de Pinheiros"')['Metragem'].mean()
# Out:
# 433.4449877750611

# %%
dados.query('Bairro == "Jardim Guedala"')['Metragem'].mean()
# Out:
# 2486.640198511166

# %%
dados.query('Bairro == "Jardim Paulista"')['Metragem'].mean()
# Out:
# 486.2977346278317

# %%
dados.query('Bairro == "Jardim Europa"')['Metragem'].mean()
# Out:
# 561.5666666666667

# %%
dados.groupby('Bairro')['Metragem'].mean()
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
bairros = input("Digite o bairro: ")
dados["Bairro"] == ("bairros")
# Out:
# Digite o bairro: Morumbi
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_bairro = dados["Bairro"].value_counts()
imoveis_bairro.head(20).plot()

# %%
imoveis_bairro = dados["Bairro"].value_counts()
imoveis_bairro.head(20).plot.pie()

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
imoveis_lapa1["Metragem"].median()
# Out:
# 251.0

# %%
imoveis_lapa1["Metragem"].max()
# Out:
# 700

# %%
imoveis_lapa1["Metragem"].min()
# Out:
# 37

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %%
dados.describe(include='all')
# Out:
#                       Rua             Bairro     Cidade       Metragem  \
# count                6574               9996      10008   10008.000000
# unique               3130                701          1            NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo            NaN
# freq                   24                409      10008            NaN
# mean                  NaN                NaN        NaN     442.300659
# std                   NaN                NaN        NaN    7515.379389
# min                   NaN                NaN        NaN      10.000000
# 25%                   NaN                NaN        NaN     173.000000
# 50%                   NaN                NaN        NaN     290.000000
# 75%                   NaN                NaN        NaN     460.250000
# max                   NaN                NaN        NaN  750000.000000
#
#              Quartos     Banheiros         Vagas         Valor
# ...

# %%
dados ['Rua'].describe()
# Out:
# count                  6574
# unique                 3130
# top       Rua Alberto Faria
# freq                     24
# Name: Rua, dtype: object

# %%
sem_rua=dados['Rua'].isnull()
sem_rua
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Rua, Length: 10008, dtype: bool
